# %% [markdown]
# # Thirukkural Dataset Exploration
# Loading the Thirukkural CSV dataset into a Pandas DataFrame for easier viewing.

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# Load the dataset
df = pd.read_csv('data/KURAL_DATASET.csv')

# Display the first few rows of the dataframe
df.head()
